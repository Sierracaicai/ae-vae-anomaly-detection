# %%
# run .py file
# %run /content/load_data.py
# %run /content/eda_tools.py

# %%
from google.colab import drive
drive.mount('/content/drive')

# set path
data_path = "/content/drive/MyDrive/projects/ae-vae-anomaly-detection/data/raw/UNSW-NB15_1.csv"
# Out:
# Mounted at /content/drive

# %%
df = load_raw_data(data_path)
# Out:
# /content/load_data.py:28: DtypeWarning: Columns (1,3,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, header=None)
# ✅ Loaded data: 700001 rows × 49 columns

# %%
# EDA
overview_dataframe(df)
plot_missing_heatmap(df)
plot_dtype_distribution(df)
plot_label_distribution(df)
plot_attack_category_distribution(df)
features_to_plot = select_visualization_candidates(df)
plot_feature_hist(df, features_to_plot, bins=50)
plot_correlation_heatmap(df)
outliers = detect_outliers_zscore(df)
# Out:
# 🔎 Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700001 entries, 0 to 700000
# Data columns (total 49 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   srcip             700001 non-null  object
#  1   sport             700001 non-null  object
#  2   dstip             700001 non-null  object
#  3   dsport            700001 non-null  object
#  4   proto             700001 non-null  object
#  5   state             700001 non-null  object
#  6   dur               700001 non-null  float64
#  7   sbytes            700001 non-null  int64
#  8   dbytes            700001 non-null  int64
#  9   sttl              700001 non-null  int64
#  10  dttl              700001 non-null  int64
#  11  sloss             700001 non-null  int64
#  12  dloss             700001 non-null  int64
#  13  service           700001 non-null  object
#  14  sload             700001 non-null  float64
# ...

# %%
detect_rare_categories(df, categorical_cols=['proto'])
# Out:
# 🔎 Frequency analysis for column 'proto':
#        overall_freq  normal_freq  anomaly_freq
# proto
# tcp        0.706766     0.715913      0.427684
# udp        0.279255     0.275017      0.408553
# unas       0.002060     0.000000      0.064911
# ospf       0.003023     0.002821      0.009183
# sctp       0.000160     0.000000      0.005042
# ...             ...          ...           ...
# esp        0.000003     0.000003      0.000000
# igmp       0.000023     0.000024      0.000000
# icmp       0.000214     0.000221      0.000000
# rtp        0.000001     0.000001      0.000000
# udt        0.000006     0.000006      0.000000
#
# [135 rows x 3 columns]
# 🗂 Rare categories in 'proto' (<1.0% overall):
#        overall_freq  normal_freq  anomaly_freq
# proto
# unas       0.002060     0.000000      0.064911
# ospf       0.003023     0.002821      0.009183
# sctp       0.000160     0.000000      0.005042
# any        0.000060     0.000000      0.001891
# ...
